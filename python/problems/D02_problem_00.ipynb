# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
print(btc)
# Out:
# {'opening_price': '4315000', 'closing_price': '4280000', 'min_price': '4250000', 'max_price': '4339000', 'average_price': '4301646.0022', 'units_traded': '18072.09858032', 'volume_1day': '18072.09858032', 'volume_7day': '56272.97174155', 'buy_price': '4280000', 'sell_price': '4281000', '24H_fluctate': '-35000', '24H_fluctate_rate': '-0.81', 'date': '1546567298686'}

# %%
# 아래에 코드를 작성하세요.
#시가 = 시작가격

bdp = float(btc['max_price']) - float(btc['min_price'])
# print(bdp)
gijun = float(btc['opening_price']) + bdp
# print(gijun)
if gijun > float(btc['max_price']):
    print("상승장")
else:
    print("하락장")
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
import pprint
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint.pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-5.8',
#          '24H_fluctate_rate': '-5.74',
#          'average_price': '103.2452',
#          'buy_price': '95.2',
#          'closing_price': '95.2',
#          'max_price': '115',
#          'min_price': '94.1',
#          'opening_price': '101',
#          'sell_price': '95.8',
#          'units_traded': '11650299.79911732',
#          'volume_1day': '11650299.79911732',
#          'volume_7day': '50432375.121495697921657788'},
#  'ADA': {'24H_fluctate': '-2.4',
#          '24H_fluctate_rate': '-3.08',
#          'average_price': '77.1813',
#          'buy_price': '75.5',
#          'closing_price': '75.5',
#          'max_price': '79.3',
#          'min_price': '75.1',
#          'opening_price': '77.9',
#          'sell_price': '76.3',
#          'units_traded': '2079809.74926183',
#          'volume_1day': '2079809.74926183',
#          'volume_7day': '39798371.19645277'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-21',
#         '24H_fluctate_rate': '-1.27',
#         'average_price': '1632.6614',
#         'buy_price': '1603',
#         'closing_price': '1621',
#         'max_price': '1678',
#         'min_price': '1600',
#         'opening_price': '1642',
#         'sell_price': '1621',
#         'units_traded': '68038.66705548',
#         'volume_1day': '68038.66705548',
#         'volume_7day': '1899055.95406807896023566'},
#  'AMO': {'24H_fluctate': '-0.19',
#          '24H_fluctate_rate': '-10.73',
#          'average_price': '1.6968',
#          'buy_price': '1.57',
#          'closing_price': '1.58',
#          'max_price': '1.78',
#          'min_price': '1.56',
#          'opening_price': '1.77',
#          'sell_price': '1.58',
#          'units_traded': '711502691.52436068',
#          'volume_1day': '711502691.52436068',
#          'volume_7day': '24110882415.209791963542864948'},
#  'BAT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.01',
#          'average_price': '147.0668',
#          'buy_price': '146',
#          'closing_price': '146',
#          'max_price': '154',
#          'min_price': '144',
#          'opening_price': '149',
#          'sell_price': '148',
#          'units_traded': '1514507.80329052',
#          'volume_1day': '1514507.80329052',
#          'volume_7day': '7020801.169710630100902915'},
#  'BCD': {'24H_fluctate': '-30',
#          '24H_fluctate_rate': '-2.90',
#          'average_price': '1016.0559',
#          'buy_price': '1001',
#          'closing_price': '1003',
#          'max_price': '1040',
#          'min_price': '997',
#          'opening_price': '1033',
#          'sell_price': '1005',
#          'units_traded': '119335.05095646',
#          'volume_1day': '119335.05095646',
#          'volume_7day': '1807577.86270526'},
#  'BCH': {'24H_fluctate': '-10900',
#          '24H_fluctate_rate': '-5.69',
#          'average_price': '183887.5626',
#          'buy_price': '179900',
#          'closing_price': '180400',
#          'max_price': '191500',
#          'min_price': '177300',
#          'opening_price': '191300',
#          'sell_price': '180000',
#          'units_traded': '46632.55123284',
#          'volume_1day': '46632.55123284',
#          'volume_7day': '553088.48935555'},
#  'BHPC': {'24H_fluctate': '-17',
#           '24H_fluctate_rate': '-1.86',
#           'average_price': '909.7011',
#           'buy_price': '894',
#           'closing_price': '894',
#           'max_price': '927',
#           'min_price': '890',
#           'opening_price': '911',
#           'sell_price': '905',
#           'units_traded': '485797.70485765',
#           'volume_1day': '485797.70485765',
#           'volume_7day': '8357645.407261527652769304'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-4800',
#          '24H_fluctate_rate': '-4.62',
#          'average_price': '100419.3175',
#          'buy_price': '98900',
#          'closing_price': '98900',
#          'max_price': '104100',
#          'min_price': '97400',
#          'opening_price': '103700',
#          'sell_price': '99200',
#          'units_traded': '23051.17282066',
#          'volume_1day': '23051.17282066',
#          'volume_7day': '269444.52296815'},
#  'BTC': {'24H_fluctate': '-49000',
#          '24H_fluctate_rate': '-1.13',
#          'average_price': '4301082.0223',
#          'buy_price': '4272000',
#          'closing_price': '4274000',
#          'max_price': '4339000',
#          'min_price': '4250000',
#          'opening_price': '4323000',
#          'sell_price': '4274000',
#          'units_traded': '18049.48586827',
#          'volume_1day': '18049.48586827',
#          'volume_7day': '56249.68540662'},
#  'BTG': {'24H_fluctate': '-440',
#          '24H_fluctate_rate': '-2.96',
#          'average_price': '14482.1719',
#          'buy_price': '14390',
#          'closing_price': '14420',
#          'max_price': '15040',
#          'min_price': '12970',
#          'opening_price': '14860',
#          'sell_price': '14420',
#          'units_traded': '22314519.20873701',
#          'volume_1day': '22314519.20873701',
#          'volume_7day': '98626917.43078745'},
#  'BZNT': {'24H_fluctate': '-0.5',
#           '24H_fluctate_rate': '-1.79',
#           'average_price': '27.932',
#           'buy_price': '27.4',
#           'closing_price': '27.4',
#           'max_price': '29.3',
#           'min_price': '27',
#           'opening_price': '27.9',
#           'sell_price': '28',
#           'units_traded': '35713966.72194837',
#           'volume_1day': '35713966.72194837',
#           'volume_7day': '191409597.621133452831885565'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '-1.2',
#          '24H_fluctate_rate': '-3.35',
#          'average_price': '34.5704',
#          'buy_price': '33.9',
#          'closing_price': '34.6',
#          'max_price': '36.2',
#          'min_price': '32.4',
#          'opening_price': '35.8',
#          'sell_price': '34.4',
#          'units_traded': '4621146.03225042',
#          'volume_1day': '4621146.03225042',
#          'volume_7day': '36373457.702795702860476475'},
#  'CTXC': {'24H_fluctate': '-3',
#           '24H_fluctate_rate': '-2.50',
#           'average_price': '118.0494',
#           'buy_price': '115',
#           'closing_price': '117',
#           'max_price': '124',
#           'min_price': '113',
#           'opening_price': '120',
#           'sell_price': '117',
#           'units_traded': '1320559.23731294',
#           'volume_1day': '1320559.23731294',
#           'volume_7day': '11484514.776721014673753123'},
#  'DASH': {'24H_fluctate': '-3050',
#           '24H_fluctate_rate': '-3.25',
#           'average_price': '90719.3819',
#           'buy_price': '90400',
#           'closing_price': '90550',
#           'max_price': '93600',
#           'min_price': '88100',
#           'opening_price': '93600',
#           'sell_price': '90550',
#           'units_traded': '3633189.60023308',
#           'volume_1day': '3633189.60023308',
#           'volume_7day': '32121248.17752674'},
#  'ELF': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '3.90',
#          'average_price': '132.2371',
#          'buy_price': '133',
#          'closing_price': '133',
#          'max_price': '139',
#          'min_price': '125',
#          'opening_price': '128',
#          'sell_price': '135',
#          'units_traded': '5142668.88965202',
#          'volume_1day': '5142668.88965202',
#          'volume_7day': '18443952.117588335405889591'},
#  'ENJ': {'24H_fluctate': '-1.7',
#          '24H_fluctate_rate': '-3.79',
#          'average_price': '44.0176',
#          'buy_price': '43.1',
#          'closing_price': '43.1',
#          'max_price': '45.7',
#          'min_price': '42.6',
#          'opening_price': '44.8',
#          'sell_price': '43.3',
#          'units_traded': '3425693.38339568',
#          'volume_1day': '3425693.38339568',
#          'volume_7day': '23035150.208258192816118614'},
#  'EOS': {'24H_fluctate': '-143',
#          '24H_fluctate_rate': '-4.56',
#          'average_price': '3045.9172',
#          'buy_price': '2986',
#          'closing_price': '2991',
#          'max_price': '3166',
#          'min_price': '2930',
#          'opening_price': '3134',
#          'sell_price': '2990',
#          'units_traded': '2399505.84533502',
#          'volume_1day': '2399505.84533502',
#          'volume_7day': '22716597.28025381'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-280',
#          '24H_fluctate_rate': '-4.70',
#          'average_price': '5779.2471',
#          'buy_price': '5665',
#          'closing_price': '5670',
#          'max_price': '5995',
#          'min_price': '5640',
#          'opening_price': '5950',
#          'sell_price': '5670',
#          'units_traded': '528523.15529124',
#          'volume_1day': '528523.15529124',
#          'volume_7day': '1869685.171114439873039507'},
#  'ETH': {'24H_fluctate': '-4400',
#          '24H_fluctate_rate': '-2.57',
#          'average_price': '168129.7178',
#          'buy_price': '166300',
#          'closing_price': '166300',
#          'max_price': '173800',
#          'min_price': '163500',
#          'opening_price': '170700',
#          'sell_price': '166400',
#          'units_traded': '581045.19729178',
#          'volume_1day': '581045.19729178',
#          'volume_7day': '1970912.035587088952984616'},
#  'ETHOS': {'24H_fluctate': '-18',
#            '24H_fluctate_rate': '-1.61',
#            'average_price': '1107.7564',
#            'buy_price': '1094',
#            'closing_price': '1095',
#            'max_price': '1177',
#            'min_price': '1050',
#            'opening_price': '1113',
#            'sell_price': '1095',
#            'units_traded': '255439.82987046',
#            'volume_1day': '255439.82987046',
#            'volume_7day': '6309355.46066809'},
#  'GNT': {'24H_fluctate': '-1.6',
#          '24H_fluctate_rate': '-2.06',
#          'average_price': '76.5073',
#          'buy_price': '76',
#          'closing_price': '76',
#          'max_price': '78.5',
#          'min_price': '75.3',
#          'opening_price': '77.6',
#          'sell_price': '76.2',
#          'units_traded': '1058382.69129068',
#          'volume_1day': '1058382.69129068',
#          'volume_7day': '37311327.099545753986240579'},
#  'GTO': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-1.36',
#          'average_price': '74.1117',
#          'buy_price': '72.1',
#          'closing_price': '72.1',
#          'max_price': '78.1',
#          'min_price': '71.2',
#          'opening_price': '73.1',
#          'sell_price': '73.2',
#          'units_traded': '2218769.10022207',
#          'volume_1day': '2218769.10022207',
#          'volume_7day': '24902508.93005879'},
#  'HC': {'24H_fluctate': '3',
#         '24H_fluctate_rate': '0.20',
#         'average_price': '1444.6658',
#         'buy_price': '1414',
#         'closing_price': '1433',
#         'max_price': '1512',
#         'min_price': '1380',
#         'opening_price': '1430',
#         'sell_price': '1433',
#         'units_traded': '81431.83243315',
#         'volume_1day': '81431.83243315',
#         'volume_7day': '888085.74850032'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '4',
#          '24H_fluctate_rate': '1.39',
#          'average_price': '294.9227',
#          'buy_price': '290',
#          'closing_price': '291',
#          'max_price': '318',
#          'min_price': '281',
#          'opening_price': '287',
#          'sell_price': '291',
#          'units_traded': '2119293.79156089',
#          'volume_1day': '2119293.79156089',
#          'volume_7day': '5005815.059527308297395376'},
#  'INS': {'24H_fluctate': '20',
#          '24H_fluctate_rate': '6.06',
#          'average_price': '339.5017',
#          'buy_price': '348',
#          'closing_price': '350',
#          'max_price': '366',
#          'min_price': '316',
#          'opening_price': '330',
#          'sell_price': '350',
#          'units_traded': '4359976.3135279',
#          'volume_1day': '4359976.3135279',
#          'volume_7day': '11871274.9261243662'},
#  'IOST': {'24H_fluctate': '-0.11',
#           '24H_fluctate_rate': '-1.70',
#           'average_price': '6.33',
#           'buy_price': '6.27',
#           'closing_price': '6.36',
#           'max_price': '6.52',
#           'min_price': '6.16',
#           'opening_price': '6.47',
#           'sell_price': '6.35',
#           'units_traded': '422039094.81334684',
#           'volume_1day': '422039094.81334684',
#           'volume_7day': '1445277134.82627073474677631'},
#  'ITC': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-2.85',
#          'average_price': '136.7054',
#          'buy_price': '135',
#          'closing_price': '136',
#          'max_price': '141',
#          'min_price': '133',
#          'opening_price': '140',
#          'sell_price': '136',
#          'units_traded': '1489509.17759136',
#          'volume_1day': '1489509.17759136',
#          'volume_7day': '17661410.793570639705758781'},
#  'KNC': {'24H_fluctate': '-7',
#          '24H_fluctate_rate': '-3.80',
#          'average_price': '179.5911',
#          'buy_price': '176',
#          'closing_price': '177',
#          'max_price': '185',
#          'min_price': '173',
#          'opening_price': '184',
#          'sell_price': '177',
#          'units_traded': '818911.74975387',
#          'volume_1day': '818911.74975387',
#          'volume_7day': '7217732.282790646089975132'},
#  'LINK': {'24H_fluctate': '52',
#           '24H_fluctate_rate': '14.24',
#           'average_price': '403.432',
#           'buy_price': '417',
#           'closing_price': '417',
#           'max_price': '446',
#           'min_price': '358',
#           'opening_price': '365',
#           'sell_price': '418',
#           'units_traded': '12435815.65125239',
#           'volume_1day': '12435815.65125239',
#           'volume_7day': '16575128.686441857328008566'},
#  'LOOM': {'24H_fluctate': '-1.9',
#           '24H_fluctate_rate': '-3.38',
#           'average_price': '57.6718',
#           'buy_price': '54.3',
#           'closing_price': '54.3',
#           'max_price': '63.8',
#           'min_price': '53.1',
#           'opening_price': '56.2',
#           'sell_price': '54.9',
#           'units_traded': '23687941.67166854',
#           'volume_1day': '23687941.67166854',
#           'volume_7day': '47015184.508444511561186799'},
#  'LRC': {'24H_fluctate': '-28',
#          '24H_fluctate_rate': '-4.75',
#          'average_price': '577',
#          'buy_price': '560',
#          'closing_price': '561',
#          'max_price': '595',
#          'min_price': '561',
#          'opening_price': '589',
#          'sell_price': '561',
#          'units_traded': '137682.80128059',
#          'volume_1day': '137682.80128059',
#          'volume_7day': '2920561.661871617643527395'},
#  'LTC': {'24H_fluctate': '-1050',
#          '24H_fluctate_rate': '-2.86',
#          'average_price': '35937.8814',
#          'buy_price': '35580',
#          'closing_price': '35560',
#          'max_price': '36920',
#          'min_price': '34940',
#          'opening_price': '36610',
#          'sell_price': '35680',
#          'units_traded': '12194.68539976',
#          'volume_1day': '12194.68539976',
#          'volume_7day': '176071.76442017'},
#  'MCO': {'24H_fluctate': '-34',
#          '24H_fluctate_rate': '-1.30',
#          'average_price': '2584.1221',
#          'buy_price': '2581',
#          'closing_price': '2581',
#          'max_price': '2639',
#          'min_price': '2533',
#          'opening_price': '2615',
#          'sell_price': '2621',
#          'units_traded': '804333.63460361',
#          'volume_1day': '804333.63460361',
#          'volume_7day': '1917843.15067829'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-2.4',
#           '24H_fluctate_rate': '-3.37',
#           'average_price': '69.8461',
#           'buy_price': '68.8',
#           'closing_price': '68.8',
#           'max_price': '71.4',
#           'min_price': '68.3',
#           'opening_price': '71.2',
#           'sell_price': '69',
#           'units_traded': '9193831.83840668',
#           'volume_1day': '9193831.83840668',
#           'volume_7day': '106728486.19630550599621313'},
#  'OCN': {'24H_fluctate': '-0.25',
#          '24H_fluctate_rate': '-6.20',
#          'average_price': '3.8449',
#          'buy_price': '3.78',
#          'closing_price': '3.78',
#          'max_price': '4.03',
#          'min_price': '3.67',
#          'opening_price': '4.03',
#          'sell_price': '3.8',
#          'units_traded': '56173991.37058849',
#          'volume_1day': '56173991.37058849',
#          'volume_7day': '1602156605.471413560050201454'},
#  'OMG': {'24H_fluctate': '-25',
#          '24H_fluctate_rate': '-1.48',
#          'average_price': '1646.8978',
#          'buy_price': '1635',
#          'closing_price': '1654',
#          'max_price': '1691',
#          'min_price': '1612',
#          'opening_price': '1679',
#          'sell_price': '1654',
#          'units_traded': '1247732.21474469',
#          'volume_1day': '1247732.21474469',
#          'volume_7day': '10925930.605121818906013623'},
#  'PAY': {'24H_fluctate': '-69',
#          '24H_fluctate_rate': '-3.81',
#          'average_price': '1787.3513',
#          'buy_price': '1739',
#          'closing_price': '1741',
#          'max_price': '1845',
#          'min_price': '1730',
#          'opening_price': '1810',
#          'sell_price': '1740',
#          'units_traded': '192284.52030496',
#          'volume_1day': '192284.52030496',
#          'volume_7day': '8390490.896237287598933692'},
#  'PIVX': {'24H_fluctate': '-56',
#           '24H_fluctate_rate': '-5.76',
#           'average_price': '939.6946',
#           'buy_price': '916',
#           'closing_price': '916',
#           'max_price': '973',
#           'min_price': '914',
#           'opening_price': '972',
#           'sell_price': '926',
#           'units_traded': '155066.73860544',
#           'volume_1day': '155066.73860544',
#           'volume_7day': '10439469.89094645'},
#  'PLY': {'24H_fluctate': '-0.9',
#          '24H_fluctate_rate': '-2.34',
#          'average_price': '38.1645',
#          'buy_price': '37.1',
#          'closing_price': '37.5',
#          'max_price': '40',
#          'min_price': '36.4',
#          'opening_price': '38.4',
#          'sell_price': '37.4',
#          'units_traded': '10194645.2988848',
#          'volume_1day': '10194645.2988848',
#          'volume_7day': '108943533.996038524'},
#  'POLY': {'24H_fluctate': '-4',
#           '24H_fluctate_rate': '-2.50',
#           'average_price': '157.4337',
#           'buy_price': '156',
#           'closing_price': '156',
#           'max_price': '162',
#           'min_price': '155',
#           'opening_price': '160',
#           'sell_price': '158',
#           'units_traded': '1215591.55399114',
#           'volume_1day': '1215591.55399114',
#           'volume_7day': '9967063.026797255355654461'},
#  'POWR': {'24H_fluctate': '-18',
#           '24H_fluctate_rate': '-3.32',
#           'average_price': '528.8419',
#           'buy_price': '517',
#           'closing_price': '523',
#           'max_price': '545',
#           'min_price': '512',
#           'opening_price': '541',
#           'sell_price': '524',
#           'units_traded': '426062.69365944',
#           'volume_1day': '426062.69365944',
#           'volume_7day': '6128317.16743961'},
#  'PPT': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-0.59',
#          'average_price': '1663.0348',
#          'buy_price': '1651',
#          'closing_price': '1670',
#          'max_price': '1691',
#          'min_price': '1621',
#          'opening_price': '1680',
#          'sell_price': '1669',
#          'units_traded': '37174.5843',
#          'volume_1day': '37174.5843',
#          'volume_7day': '689521.24376665'},
#  'PST': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-3.53',
#          'average_price': '111.5239',
#          'buy_price': '109',
#          'closing_price': '109',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '113',
#          'sell_price': '110',
#          'units_traded': '824112.83356885',
#          'volume_1day': '824112.83356885',
#          'volume_7day': '9430901.297611780616582618'},
#  'QTUM': {'24H_fluctate': '-84',
#           '24H_fluctate_rate': '-3.28',
#           'average_price': '2494.961',
#           'buy_price': '2477',
#           'closing_price': '2476',
#           'max_price': '2567',
#           'min_price': '2449',
#           'opening_price': '2560',
#           'sell_price': '2484',
#           'units_traded': '748668.01954719',
#           'volume_1day': '748668.01954719',
#           'volume_7day': '3124845.2860956'},
#  'RDN': {'24H_fluctate': '-36',
#          '24H_fluctate_rate': '-10.74',
#          'average_price': '311.7311',
#          'buy_price': '299',
#          'closing_price': '299',
#          'max_price': '345',
#          'min_price': '279',
#          'opening_price': '335',
#          'sell_price': '302',
#          'units_traded': '7274903.59749332',
#          'volume_1day': '7274903.59749332',
#          'volume_7day': '25517778.547742721353021321'},
#  'REP': {'24H_fluctate': '-2600',
#          '24H_fluctate_rate': '-2.65',
#          'average_price': '96881.1659',
#          'buy_price': '95400',
#          'closing_price': '95400',
#          'max_price': '99300',
#          'min_price': '94800',
#          'opening_price': '98000',
#          'sell_price': '96200',
#          'units_traded': '3572.68105605',
#          'volume_1day': '3572.68105605',
#          'volume_7day': '94140.077748120518075148'},
#  'RNT': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.69',
#          'average_price': '145.6039',
#          'buy_price': '141',
#          'closing_price': '142',
#          'max_price': '183',
#          'min_price': '116',
#          'opening_price': '143',
#          'sell_price': '142',
#          'units_traded': '82890937.24257222',
#          'volume_1day': '82890937.24257222',
#          'volume_7day': '185564007.746942647476018077'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.1264',
#          'buy_price': '0.12',
#          'closing_price': '0.13',
#          'max_price': '0.13',
#          'min_price': '0.12',
#          'opening_price': '0.13',
#          'sell_price': '0.13',
#          'units_traded': '42614384956.95709231',
#          'volume_1day': '42614384956.95709231',
#          'volume_7day': '216861685738.120281660303161222'},
#  'SALT': {'24H_fluctate': '-15',
#           '24H_fluctate_rate': '-5.37',
#           'average_price': '273.692',
#           'buy_price': '264',
#           'closing_price': '264',
#           'max_price': '289',
#           'min_price': '262',
#           'opening_price': '279',
#           'sell_price': '266',
#           'units_traded': '1451110.49371115',
#           'volume_1day': '1451110.49371115',
#           'volume_7day': '12798589.11242145'},
#  'SNT': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '116.4868',
#          'buy_price': '115',
#          'closing_price': '116',
#          'max_price': '120',
#          'min_price': '112',
#          'opening_price': '116',
#          'sell_price': '116',
#          'units_traded': '1695262.71923482',
#          'volume_1day': '1695262.71923482',
#          'volume_7day': '24198458.578611629713343892'},
#  'STEEM': {'24H_fluctate': '-3',
#            '24H_fluctate_rate': '-0.16',
#            'average_price': '1825.4043',
#            'buy_price': '1806',
#            'closing_price': '1838',
#            'max_price': '1875',
#            'min_price': '1784',
#            'opening_price': '1841',
#            'sell_price': '1838',
#            'units_traded': '75159.6777933',
#            'volume_1day': '75159.6777933',
#            'volume_7day': '1365910.7952473'},
#  'STRAT': {'24H_fluctate': '-1',
#            '24H_fluctate_rate': '-0.03',
#            'average_price': '2843.0223',
#            'buy_price': '2820',
#            'closing_price': '2884',
#            'max_price': '2919',
#            'min_price': '2751',
#            'opening_price': '2885',
#            'sell_price': '2869',
#            'units_traded': '24423.48345097',
#            'volume_1day': '24423.48345097',
#            'volume_7day': '487980.7504285'},
#  'THETA': {'24H_fluctate': '-0.9',
#            '24H_fluctate_rate': '-1.57',
#            'average_price': '57.9945',
#            'buy_price': '56.2',
#            'closing_price': '56.3',
#            'max_price': '62.8',
#            'min_price': '55.4',
#            'opening_price': '57.2',
#            'sell_price': '56.4',
#            'units_traded': '18229061.8330032',
#            'volume_1day': '18229061.8330032',
#            'volume_7day': '91921623.812888079266342968'},
#  'TMTG': {'24H_fluctate': '-0.31',
#           '24H_fluctate_rate': '-3.70',
#           'average_price': '8.2466',
#           'buy_price': '8.05',
#           'closing_price': '8.05',
#           'max_price': '8.41',
#           'min_price': '8.03',
#           'opening_price': '8.36',
#           'sell_price': '8.11',
#           'units_traded': '206617523.73258141',
#           'volume_1day': '206617523.73258141',
#           'volume_7day': '1483207734.948487940161481648'},
#  'TRUE': {'24H_fluctate': '20',
#           '24H_fluctate_rate': '6.87',
#           'average_price': '306.7715',
#           'buy_price': '311',
#           'closing_price': '311',
#           'max_price': '337',
#           'min_price': '287',
#           'opening_price': '291',
#           'sell_price': '313',
#           'units_traded': '2292054.22533346',
#           'volume_1day': '2292054.22533346',
#           'volume_7day': '8412694.662813637773447992'},
#  'TRX': {'24H_fluctate': '0.2',
#          '24H_fluctate_rate': '0.90',
#          'average_price': '22.4334',
#          'buy_price': '22.3',
#          'closing_price': '22.3',
#          'max_price': '23.2',
#          'min_price': '21.8',
#          'opening_price': '22.1',
#          'sell_price': '22.4',
#          'units_traded': '221622983.42550232',
#          'volume_1day': '221622983.42550232',
#          'volume_7day': '940031860.92506475'},
#  'VET': {'24H_fluctate': '-0.22',
#          '24H_fluctate_rate': '-3.02',
#          'average_price': '7.193',
#          'buy_price': '7.06',
#          'closing_price': '7.06',
#          'max_price': '7.35',
#          'min_price': '7.06',
#          'opening_price': '7.28',
#          'sell_price': '7.13',
#          'units_traded': '8069066.75728701',
#          'volume_1day': '8069066.75728701',
#          'volume_7day': '72340056.52486151956123794'},
#  'WAVES': {'24H_fluctate': '5',
#            '24H_fluctate_rate': '0.14',
#            'average_price': '3483.8014',
#            'buy_price': '3441',
#            'closing_price': '3459',
#            'max_price': '3550',
#            'min_price': '3419',
#            'opening_price': '3454',
#            'sell_price': '3477',
#            'units_traded': '175682.36831167',
#            'volume_1day': '175682.36831167',
#            'volume_7day': '2678650.77250588'},
#  'WAX': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.86',
#          'average_price': '105.6142',
#          'buy_price': '104',
#          'closing_price': '105',
#          'max_price': '108',
#          'min_price': '104',
#          'opening_price': '107',
#          'sell_price': '105',
#          'units_traded': '853831.72129347',
#          'volume_1day': '853831.72129347',
#          'volume_7day': '17692031.09044218'},
#  'WET': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '14.0789',
#          'buy_price': '13.9',
#          'closing_price': '14',
#          'max_price': '14.4',
#          'min_price': '13.9',
#          'opening_price': '14',
#          'sell_price': '14',
#          'units_traded': '18376527.76488711',
#          'volume_1day': '18376527.76488711',
#          'volume_7day': '194810795.677109116950969508'},
#  'WTC': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '0.39',
#          'average_price': '1285.9361',
#          'buy_price': '1268',
#          'closing_price': '1273',
#          'max_price': '1328',
#          'min_price': '1253',
#          'opening_price': '1268',
#          'sell_price': '1273',
#          'units_traded': '226967.89657532',
#          'volume_1day': '226967.89657532',
#          'volume_7day': '2368085.320817056649794688'},
#  'XEM': {'24H_fluctate': '-1.1',
#          '24H_fluctate_rate': '-1.49',
#          'average_price': '73.2314',
#          'buy_price': '72.3',
#          'closing_price': '72.4',
#          'max_price': '75.4',
#          'min_price': '72',
#          'opening_price': '73.5',
#          'sell_price': '72.4',
#          'units_traded': '2050191.25385356',
#          'volume_1day': '2050191.25385356',
#          'volume_7day': '21649925.62323651'},
#  'XLM': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-3.07',
#          'average_price': '128.1527',
#          'buy_price': '126',
#          'closing_price': '126',
#          'max_price': '131',
#          'min_price': '126',
#          'opening_price': '130',
#          'sell_price': '127',
#          'units_traded': '4805433.55292867',
#          'volume_1day': '4805433.55292867',
#          'volume_7day': '47719691.57589247'},
#  'XMR': {'24H_fluctate': '-1600',
#          '24H_fluctate_rate': '-2.81',
#          'average_price': '55935.9206',
#          'buy_price': '55300',
#          'closing_price': '55300',
#          'max_price': '57500',
#          'min_price': '55000',
#          'opening_price': '56900',
#          'sell_price': '55500',
#          'units_traded': '13217076.81199034',
#          'volume_1day': '13217076.81199034',
#          'volume_7day': '67957475.706224596036'},
#  'XRP': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-2.43',
#          'average_price': '404.0248',
#          'buy_price': '400',
#          'closing_price': '400',
#          'max_price': '413',
#          'min_price': '397',
#          'opening_price': '410',
#          'sell_price': '401',
#          'units_traded': '46171473.86776765',
#          'volume_1day': '46171473.86776765',
#          'volume_7day': '473997315.01778227'},
#  'XVG': {'24H_fluctate': '-0.11',
#          '24H_fluctate_rate': '-1.38',
#          'average_price': '7.8694',
#          'buy_price': '7.75',
#          'closing_price': '7.86',
#          'max_price': '8.04',
#          'min_price': '7.72',
#          'opening_price': '7.97',
#          'sell_price': '7.86',
#          'units_traded': '5885501.15702363',
#          'volume_1day': '5885501.15702363',
#          'volume_7day': '51439691.33454364'},
#  'ZEC': {'24H_fluctate': '-1750',
#          '24H_fluctate_rate': '-2.60',
#          'average_price': '65701.7427',
#          'buy_price': '65000',
#          'closing_price': '65350',
#          'max_price': '67350',
#          'min_price': '64150',
#          'opening_price': '67100',
#          'sell_price': '65250',
#          'units_traded': '36028.13764304',
#          'volume_1day': '36028.13764304',
#          'volume_7day': '33685223.47652229'},
#  'ZIL': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-0.88',
#          'average_price': '22.3693',
#          'buy_price': '22.2',
#          'closing_price': '22.3',
#          'max_price': '22.7',
#          'min_price': '22',
#          'opening_price': '22.5',
#          'sell_price': '22.3',
#          'units_traded': '19157729.96458188',
#          'volume_1day': '19157729.96458188',
#          'volume_7day': '456953117.521413354635'},
#  'ZRX': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.27',
#          'average_price': '363.8352',
#          'buy_price': '359',
#          'closing_price': '361',
#          'max_price': '370',
#          'min_price': '356',
#          'opening_price': '360',
#          'sell_price': '361',
#          'units_traded': '997631.62395099',
#          'volume_1day': '997631.62395099',
#          'volume_7day': '5917679.394681677377380573'},
#  'date': '1546568402385'}

# %%
# 아래에 코드를 작성하세요.
# bdp = int(btc['max_price']) - int(btc['min_price'])
# # print(bdp)
# gijun = int(btc['opening_price']) + bdp
# # print(gijun)
# if gijun > int(btc['max_price']):
#     print("상승장")
# else:
#     print("하락장")
for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value['max_price']) - float(value['min_price'])
        gijun = float(value['opening_price']) + bdp
        if gijun > float(value['max_price']):
            print(f"{key:5}", "상승장")
        else:
            print(f"{key:5}", "하락장")
# Out:
# BTC   상승장
# ETH   상승장
# DASH  상승장
# LTC   상승장
# ETC   상승장
# XRP   상승장
# BCH   상승장
# XMR   상승장
# ZEC   상승장
# QTUM  상승장
# BTG   상승장
# EOS   상승장
# ICX   상승장
# VET   상승장
# TRX   상승장
# ELF   상승장
# MITH  상승장
# MCO   상승장
# OMG   상승장
# KNC   상승장
# GNT   상승장
# ZIL   상승장
# ETHOS 상승장
# PAY   상승장
# WAX   상승장
# POWR  상승장
# LRC   상승장
# GTO   상승장
# STEEM 상승장
# STRAT 상승장
# ZRX   상승장
# REP   상승장
# AE    상승장
# XEM   상승장
# SNT   상승장
# ADA   상승장
# PPT   상승장
# CTXC  상승장
# CMT   상승장
# THETA 상승장
# WTC   상승장
# ITC   상승장
# TRUE  상승장
# ABT   상승장
# RNT   상승장
# PLY   상승장
# WAVES 상승장
# LINK  상승장
# ENJ   상승장
# PST   상승장
# SALT  상승장
# RDN   상승장
# LOOM  상승장
# BHPC  상승장
# PIVX  상승장
# INS   상승장
# BCD   상승장
# BZNT  상승장
# XLM   상승장
# OCN   상승장
# BSV   상승장
# TMTG  상승장
# BAT   상승장
# WET   상승장
# XVG   상승장
# IOST  상승장
# POLY  상승장
# HC    상승장
# ROM   상승장
# AMO   상승장

# %% [markdown]
# # 행맨 게임 만들기

# %% [markdown]
# ## 답안 확인 하기
#
# > 행맨 게임을 위한 코드를 작성해봅시다.
# >
# > `isanswer(answer, letters)`는 정답 문자열(answer)과 추측 알파벳의 리스트(letters)를 받아서, True/False 결과를 반환합니다.

# %%
# 여기에 코드를 작성하세요.
def isanswer_2(answer, letters):
    
    for i in range(len(letters)):
        
        a = answer.replace(letters[i], '')
        
        return a
        
        
#         if answer_2 == []:
#             return True
#         else:
#             return False

# %%
isanswer_2('apple', ['a', 'p', 'l']) #=> False
isanswer_2('apple', ['a', 'p', 'l', 'e']) #=> True

# %%
def isanswer(answer, letters):
    if set(answer) - set(letters) == set():
        return True
    else:
        return False

# %%
isanswer('apple', ['a', 'p', 'l']) #=> False
isanswer('apple', ['a', 'p', 'l',  'e']) #=> True

# %%
a = 'apple'
b = a.replace('a', '')
b
c = b.replace('p', '')
c
# d = c.replace('l', '')
# d

# %%
z = 'apple'
x = 'aple'
set(z)-set(x)

# %% [markdown]
# ## 현재 상태 출력하기
#
# > 행맨 게임을 위한 코드를 작성해봅시다.
# >
# > `status(answer, letters)`는 정답 문자열(answer)과 추측 알파벳의 리스트(letters)를 받아서, 현재 결과를 반환합니다.

# %%
# replace
def status(answer, letters):
    corrects = set(answer) & set(letters)
    return "".join([i if i in corrects else "_" for i in answer])

# %%
status('apple', ['a', 'p', 'l']) #=> 'appl_'

# %% [markdown]
# ## 행맨 로직 만들기 - 자유코딩!
#
# > 위의 코드를 활용하여 `hangman(answer)`를 만들어봅시다!
# >
# > 사용자가 답을 맞출 때까지 진행하며, 8번내로 정답을 맞춰야 합니다.

# %%
def hangman(answer):
    while True:
        letters = input('알파벳을 입력하세요 : ')
        if len(letters) <= 8:
            n = 8
            while n>0:
                for alp in answer:
                    if alp not in letters:
                        answer = answer.replace(alp, '_')
                        n = n-1
                    else:
                        n = n-1
            if set(answer) - set(letters) == set():
                print('정답입니다')
            else:
                print('틀렸습니다')
            break
        print("너무 깁니다")
    return answer

# %%
hangman('apple')

# %%
def hangman_2(answer):
    i = 0
    man ='(@^_^@)ㄱ'
    user = ['_ ' for x in range(len(answer))]
    print(''.join(user), 'start!!')
    while i < 8:
        c = input()
        if c in answer:
            for j in range(len(answer)):
                if answer[j] == c:
                    user[j] = c
            print(''.join(user), 7-i, 'turn left')
        else:
            for k in range(i+1):
                print(man[k],end="")
            print('\n',7-i, 'turn left')
        i += 1
        if answer == ''.join(user):
            return 'you win!!'
    else:
        return '(@x_x@)ㄱ -------- Your man is dead'

# %%
hangman_2('apple')

# %%
hangman_3('apple')
# Out:
# 알파벳을 입력하세요 : z
# 틀렸습니다
# '_____'

# %% [markdown]
# # 시작하기전에
#
# <wikipedia - 객체지향 프로그래밍>
# >
# > 객체 지향 프로그래밍(영어: Object-Oriented Programming, OOP)은 컴퓨터 프 로그래밍의 패러다임의 하나이다. 객체 지향 프로그래밍은 컴퓨터 프로그램을 명령어의 목록으로 보는 시각에서 벗어나 여러 개의 독립된 단위, 즉 "객체"들의 모임으로 파악하고자 하는 것이다. 각각의 객체는 메시지를 주고받고, 데이터를 처리할 수 있다.
# >
# > 명령형 프로그래밍인 절차지향 프로그래밍에서 발전된 형태를 나타내며, 기본 구성요소는 다음과 같다.
#
# * 클래스(Class) - 같은 종류(또는 문제 해결을 위한)의 집단에 속하는 속성(attribute)과 행위(behavior)를 정의한 것으로 객체지향 프로그램의 기본적인 사용자 정의 데이터형(user define data type)이라고 할 수 있다. 클래스는 프로그래머가 아니지만 해결해야 할 문제가 속하는 영역에 종사하는 사람이라면 사용할 수 있고, 다른 클래스 또는 외부 요소와 독립적으로 디자인하여야 한다.
#
#
# * 인스턴스 - `클래스의 인스턴스`(실제로 메모리상에 할당된 것)이다. 객체는 자신 고유의 속성(attribute)을 가지며 클래스에서 정의한 행위(behavior)를 수행할 수 있다. 객체의 행위는 클래스에 정의된 행위에 대한 정의를 공유함으로써 메모리를 경제적으로 사용한다.
#
#
# * 메서드(Method) - 클래스로부터 생성된 객체를 사용하는 방법으로서 객체에 명령을 내리는 것이라 할 수 있다. 메서드는 한 객체의 속성을 조작하는 데 사용된다.
#
# 클래스는 메모리 안먹고 인스턴스부터 먹는다

# %%
# 복소수를 하나 만들어보고, 타입을 출력해봅시다.
a = 5 + 3j
print(type(a))
#complex라는 클래스에 a라는 인스턴스 할당

# %%
# 허수부랑 실수부를 함께 출력해봅시다.
print(a.real, a.imag)
#.real, .imag 는 complex 안에 있는 method를 a가 실행시키는 것

# %%
# 리스트를 하나 만들고 정렬해봅시다.
L = [5, 1, 3]
L.sort()
print(type(L))
#L은 list라는 클래스의 객체      == 인스턴스
#sort라는 method

# %%
# 리스트가 할 수 있는 것들을 알아봅시다.
print(dir(list))
#sorted는 내장함수...    밑에 꺼는 list 클래스 안에 있는 method

# %% [markdown]
# ## 실습 문제
#
# > 프로그래밍으로 나와 친구의 이름을 저장해보세요.
# >
#
# **각자의 명함과 지갑을 만들어봅시다.**
#
# * 내 생일, 전화번호, 이메일주소 정보를 담은 변수를 확인해봅시다.
#
# * 주머니(pocket)에는 돈(won)을 포함하여 현재 가지고 있는 것을 작성해보세요.
#
# * 나는 인사를 하면서 내 명함에 있는 정보 하나를 이야기합니다. `greeting` 함수를 만듭시다.
#
# * 나는 주머니에 원하는 것과 갯수를 지정하여 넣을 수 있습니다.
#
#   기존에 값이 있으면, 갯수를 추가하고 없으면 새로 만드는 `in_my_pocket` 함수를 만듭시다.
#
# **친구의 정보와 지갑도 만들어봅시다.**

# %%
# 아래에 자유롭게 코드를 작성해보세요.
my_name = 'Nam ki'
# you_name = ''
my_birthday = '1990.12.18'
my_phone = '01044691218'

my_pocket = {'돈' : 100,  '카드': 2, '신분증':1}
# your_pocket =  

def in_my_pocket(pocket, key, value):
    if key not in pocket:
        pocket.update({key:value})
        return pocket
    else:
        pocket.update({key:pocket[key]+value})
        return pocket
        
        

    
    
    
    


# print(in_my_pocket(my_pocket, '신분증', '2'))

# %%
def in_my_pocket_2(pocket, stuff, count):
    if pocket.get(stuff):
        pocket[stuff] += count
    else:
        pocket[stuff] = count
    return pocket

def greeting(name, phone):
    print(f'안녕, 나는 {name}야 내 번호는 {phone}야')

# %%
in_my_pocket(my_pocket, '돈', 200)

# %%
in_my_pocket(my_pocket, '동전', 200)

# %%
# in_my_pocket 함수를 통해 내 주머니에 내용을 추가해봅시다.

# %%
# greeting 함수를 통해 인사를 해봅시다.
def greeting(name, phone):
    print(f'안녕, 나는 {name}야 내 번호는 {phone}야')

# %%
a = {'돈': '100', '카드': '2', '신분증': '1'}
int(a['돈'])+int(a['신분증'])

# %% [markdown]
# # 클래스 및 인스턴스

# %% [markdown]
# ## 클래스
#
# ```python
# class ClassName:
#
# ```
#
# * 선언과 동시에 클래스 객체가 생성됨.
#
# * 또한, 선언된 공간은 지역 스코프로 사용된다.
#
# * 정의된 어트리뷰트 중 변수는 멤버 변수로 불리운다.
#
# * 정의된 함수(`def`)는 메서드로 불리운다.

# %%
class Person:
    pass

p = Person()
print(p)

# %%
class Person:
    name = '고길동'
    def sayhello(self):
        print(f"Hello, I'm {self.name}.")

# %% [markdown]
# * 선언시 self는 반드시 작성해주세요! 나중에 설명드립니다.

# %% [markdown]
# ## 인스턴스
#
# * 인스턴스 객체는 `ClassName()`을 호출함으로써 선언된다.
#
# * 인스턴스 객체와 클래스 객체는 서로 다른 이름 공간을 가지고 있다.
#
# * 인스턴스 -> 클래스 -> 전역 순으로 탐색을 한다.

# %%
# iu라는 클래스 Person의 인스턴스를 만들어봅시다. 
iu = Person()

# %%
# 인사하는 메서드를 호출해봅시다.
iu.sayhello()

# %%
# iu의 이름을 확인해봅시다.
iu.name

# %%
# iu로 이름을 바꿔주세요.
iu.name = 'iu'
iu.name

# %%
# iu가 인사를 합니다.
iu.sayhello()

# %%
# iu와 Person이 같은지 확인해보겠습니다.
isinstance(iu, Person)

# %%
# iu와 Person이 같은지 확인해보겠습니다.
iu

# %%
# iu를 출력해봅시다.
iu

# %%
# iu를 출력해봅시다 2.
print(iu)

# %%
# map을 만들어 비교해 봅시다.
print(map(int, '123'))

# %%
a = (1, 2)
a

# %%
b = dict(x = 11, y = 22)
b

# %%
c = list(range(10))
c. append(100)
c

# %%
print(type(a))
print(type(b))
print(type(c))
isinstance(a, tuple)
isinstance(b, dict)
isinstance(c, list)
#대표적인 내장class, 자주쓰는거는 규칙성은 없지만 앞에 소문자인 것들이 있다.

# %%
class Person:
    name = '고길동'
    def sayhello():
        print(f"Hello, I'm {name}.")

# %%
# self 있고없고
class Person:
    name = '고길동'
    def sayhello(self):
        print(f"Hello, I'm {self.name}.")
        
#self는 instance 자기 자신이다.
#걍 무조건 self로 쓰자!!!!!!!

# %%
iu = Person()
iu.sayhello()

# %% [markdown]
# ## 실습 문제 발전
#
# > 지금까지 배운 것을 통해서 Person 클래스를 만들고, 친구와 나를 표현해봅시다.
# >
# > 주머니와 정보를 가지고 있고 (멤버 변수)
# >
# > 인사(`greeting()`)와 주머니에 내용을 추가(`in_my_pocket()`)할 수 있습니다. (메서드)
# >
# > 추가적으로 `get_my_pocket()`으로 지갑에 담긴 정보를 가져와 봅시다.

# %%
# 아래에 코드를 작성해주세요.    
# name = 'Nam ki'
# phone = '01044691218'
# pocket = {'돈' : 100,  '카드': 2, '신분증':1}

class Person:
    name = 'Nam ki'
    phone = '01044691218'
    pocket = {'돈' : 100,  '카드': 2, '신분증':1}
    def in_my_pocket(self, key, value):
        if key not in self.pocket:
            self.pocket.update({key:value})
            return self.pocket
        else:
            self.pocket.update({key:self.pocket[key]+value})
            return self.pocket

    def greeting(self):
        print(f'안녕, 나는 {self.name}야 내 번호는 {self.phone}야')        
    
    def get_my_pocket(self):
        return self.pocket

# %%
# 나를 만들어 봅시다.
I = Person()
I.name = 'Hyeri'
I.name
I.phone
I.greeting()
I.get_my_pocket()
I.in_my_pocket('dollar', 5)
I.in_my_pocket('돈', 300)

#혼자할땐 주석처리하고 하나씩 살리면서 돌려보자...!

# I.in_my_pocket('동전', 200)
# I.pocket = {'캔디':100}
# I.in_my_pocket('동전', 200)

# I.greeting()

# %%
# greeting, in_my_pocket, get_my_pocket

# %%
class Person:
    def __init__(self, name, age = 0):
        self.name = name
        self.age = age
    def greeting(self):
        print(f'안녕하세요. {self.name}. {self.age}살입니다.')

# %%
p1 = Person('홍길동', 20)
p1.greeting()
# Out:
# 안녕하세요. 홍길동. 20살입니다.

# %%
p2 = Person('둘리')
p2.greeting()
# Out:
# 안녕하세요. 둘리. 0살입니다.
